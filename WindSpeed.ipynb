# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
import pickle

from statsmodels.tsa.vector_ar.var_model import VAR

import xgboost as xgb
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# # Data

# %%
df = pd.read_csv('DATAA.csv', parse_dates=[['Date', 'Time']])
df['Date_Time'] = pd.to_datetime(df.Date_Time , format = '%d/%m/%Y %H.%M.%S')
# Sort on time
df = df.sort_values(by='Date_Time')

df.head()
# Out:
#              Date_Time  No of Vehicles  Wind Speed  Visibility  Accident  \
# 23 2022-10-01 00:00:00            4523          17        16.0         3
# 0  2022-10-01 01:00:00            3434           6        16.0         3
# 1  2022-10-01 02:00:00            2229           7        16.0         5
# 2  2022-10-01 03:00:00            1583          19        16.0         4
# 3  2022-10-01 04:00:00            1360          15        16.0         3
#
#     Unnamed: 6      WS  Unnamed: 8       V  Unnamed: 10       A
# 23    -0.39542 -3954.2      2.4432  2443.2     -0.08643  -864.3
# 0     -0.13956 -1395.6      2.4432  2443.2     -0.08643  -864.3
# 1     -0.16282 -1628.2      2.4432  2443.2     -0.14405 -1440.5
# 2     -0.44194 -4419.4      2.4432  2443.2     -0.11524 -1152.4
# 3     -0.34890 -3489.0      2.4432  2443.2     -0.08643  -864.3

# %%
# Drop unnamed column
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# Drop wind speed, visibility, and accident
df = df.drop(['Wind Speed', 'Visibility', 'Accident'], axis=1)

# Only Wind Speed will be here so drop the rest
df = df.drop(['V', 'A'], axis=1)

df.head()
# Out:
#              Date_Time  No of Vehicles      WS
# 23 2022-10-01 00:00:00            4523 -3954.2
# 0  2022-10-01 01:00:00            3434 -1395.6
# 1  2022-10-01 02:00:00            2229 -1628.2
# 2  2022-10-01 03:00:00            1583 -4419.4
# 3  2022-10-01 04:00:00            1360 -3489.0

# %%
# Plot correlation matrix
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# /tmp/ipykernel_7666/3037099363.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
# <style type="text/css">
# #T_c003f_row0_col0, #T_c003f_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c003f_row0_col1, #T_c003f_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c003f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c003f_level0_col0" class="col_heading level0 col0" >No of Vehicles</th>
#       <th id="T_c003f_level0_col1" class="col_heading level0 col1" >WS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c003f_level0_row0" class="row_heading level0 row0" >No of Vehicles</th>
#       <td id="T_c003f_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_c003f_row0_col1" class="data row0 col1" >-0.023259</td>
#     </tr>
#     <tr>
#       <th id="T_c003f_level0_row1" class="row_heading level0 row1" >WS</th>
#       <td id="T_c003f_row1_col0" class="data row1 col0" >-0.023259</td>
#       <td id="T_c003f_row1_col1" class="data row1 col1" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Plot the data
df.plot(x='Date_Time', y=['No of Vehicles'], figsize=(20,10))
# Out:
# <AxesSubplot: xlabel='Date_Time'>

# %%
# Check if data is stationary
from statsmodels.tsa.stattools import adfuller

result = adfuller(df['No of Vehicles'].values)
print('ADF Statistic: %f' % result[1])
# Out:
# ADF Statistic: 0.005820

# %%
# Partial Autocorrelation
from statsmodels.graphics.tsaplots import plot_pacf

plot_pacf(df['No of Vehicles'].values, lags=50)
# Out:
# /mnt/A6E6E098E6E069CF/L4T2/Extra/ML/Notebook/env/lib/python3.10/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# The stationary test returns p value less than 0.05, so it is stationary and no transformation is needed
#
# The partial autocorrelation shows that 1-5, 7-10, 25, 30 and so on lags can be used.

# %% [markdown]
# # Split data

# %%
data = df.drop(['Date_Time'], axis=1)
data.index = df.Date_Time

#creating the train and validation set for VAR model
train = data[:int(0.8*(len(data)))]
valid = data[int(0.8*(len(data))):]

# %%
# Create dataframes for train and valid for multivariate regression
X = data.drop(['No of Vehicles'], axis=1)
y = data['No of Vehicles']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((595, 1), (149, 1), (595,), (149,))

# %%
# Add lags to the data
for i in range(1,25):
    df["lag_{}".format(i)] = df['No of Vehicles'].shift(i)
    
# Create train and test set from lagged data
df.dropna(inplace=True)
X = df.drop(['No of Vehicles', 'Date_Time'], axis=1)
y = df['No of Vehicles']

X_train_lagged, X_test_lagged, y_train_lagged, y_test_lagged = train_test_split(X, y, test_size=0.2, shuffle=False)

# %% [markdown]
# # VAR Model

# %%
forecasting_model = VAR(train)
# Out:
# /mnt/A6E6E098E6E069CF/L4T2/Extra/ML/Notebook/env/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
results_aic = []

for p in range(1,50):
    results = forecasting_model.fit(p)
    results_aic.append(results.aic)

# %%
sns.set()
plt.plot(list(np.arange(1,50,1)), results_aic)
plt.xlabel("Order")
plt.ylabel("AIC")
plt.show()

# %%
# Lowest AIC is 25, which matches the PACF plot
results = forecasting_model.fit(25)
results.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Fri, 12, May, 2023
# Time:                     21:08:20
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                    27.0230
# Nobs:                     570.000    HQIC:                   26.5488
# Log likelihood:          -8995.52    FPE:                2.50403e+11
# AIC:                      26.2454    Det(Omega_mle):     2.10963e+11
# --------------------------------------------------------------------
# Results for equation No of Vehicles
# =====================================================================================
#                         coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------
# const                    973.080971       324.080250            3.003           0.003
# L1.No of Vehicles          0.953037         0.042646           22.347           0.000
# L1.WS                     -0.006673         0.023545           -0.283           0.777
# L2.No of Vehicles         -0.061007         0.058323           -1.046           0.296
# L2.WS                      0.056303         0.024839            2.267           0.023
# L3.No of Vehicles         -0.139445         0.058181           -2.397           0.017
# L3.WS                      0.000500         0.025112            0.020           0.984
# L4.No of Vehicles          0.019183         0.058458            0.328           0.743
# L4.WS                      0.003392         0.025151            0.135           0.893
# L5.No of Vehicles         -0.101929         0.058428           -1.745           0.081
# L5.WS                     -0.044655         0.025131           -1.777           0.076
# L6.No of Vehicles          0.010556         0.058375            0.181           0.856
# L6.WS                      0.013135         0.025195            0.521           0.602
# L7.No of Vehicles          0.104553         0.058254            1.795           0.073
# L7.WS                      0.016915         0.025219            0.671           0.502
# L8.No of Vehicles         -0.036459         0.058071           -0.628           0.530
# L8.WS                      0.014127         0.025189            0.561           0.575
# L9.No of Vehicles         -0.018053         0.058065           -0.311           0.756
# L9.WS                     -0.012687         0.025087           -0.506           0.613
# L10.No of Vehicles        -0.074489         0.058131           -1.281           0.200
# L10.WS                    -0.015802         0.025161           -0.628           0.530
# L11.No of Vehicles         0.020671         0.058204            0.355           0.722
# L11.WS                    -0.005441         0.025037           -0.217           0.828
# L12.No of Vehicles         0.056064         0.058286            0.962           0.336
# L12.WS                     0.000547         0.024869            0.022           0.982
# L13.No of Vehicles        -0.053775         0.058260           -0.923           0.356
# L13.WS                     0.030452         0.024936            1.221           0.222
# L14.No of Vehicles        -0.021720         0.058349           -0.372           0.710
# L14.WS                    -0.024811         0.024864           -0.998           0.318
# L15.No of Vehicles        -0.030891         0.058576           -0.527           0.598
# L15.WS                     0.016242         0.025015            0.649           0.516
# L16.No of Vehicles         0.050182         0.058648            0.856           0.392
# L16.WS                    -0.005355         0.025015           -0.214           0.830
# L17.No of Vehicles         0.077343         0.058711            1.317           0.188
# L17.WS                    -0.019006         0.024967           -0.761           0.447
# L18.No of Vehicles        -0.151851         0.058875           -2.579           0.010
# L18.WS                     0.019407         0.024927            0.779           0.436
# L19.No of Vehicles        -0.009272         0.059183           -0.157           0.876
# L19.WS                    -0.015256         0.025028           -0.610           0.542
# L20.No of Vehicles         0.080195         0.059191            1.355           0.175
# L20.WS                     0.036597         0.025032            1.462           0.144
# L21.No of Vehicles         0.001854         0.059036            0.031           0.975
# L21.WS                    -0.024708         0.025085           -0.985           0.325
# L22.No of Vehicles         0.009814         0.059054            0.166           0.868
# L22.WS                     0.005874         0.025072            0.234           0.815
# L23.No of Vehicles         0.102251         0.058716            1.741           0.082
# L23.WS                     0.040361         0.024882            1.622           0.105
# L24.No of Vehicles         0.273897         0.058694            4.667           0.000
# L24.WS                    -0.012535         0.024702           -0.507           0.612
# L25.No of Vehicles        -0.228248         0.042726           -5.342           0.000
# L25.WS                    -0.012937         0.023439           -0.552           0.581
# =====================================================================================
#
# Results for equation WS
# =====================================================================================
#                         coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------
# const                    112.996263       605.849254            0.187           0.852
# L1.No of Vehicles         -0.006314         0.079725           -0.079           0.937
# L1.WS                      0.349987         0.044016            7.951           0.000
# L2.No of Vehicles         -0.057694         0.109031           -0.529           0.597
# L2.WS                      0.134937         0.046435            2.906           0.004
# L3.No of Vehicles          0.004403         0.108766            0.040           0.968
# L3.WS                      0.080763         0.046945            1.720           0.085
# L4.No of Vehicles          0.045580         0.109283            0.417           0.677
# L4.WS                      0.052044         0.047019            1.107           0.268
# L5.No of Vehicles         -0.107784         0.109228           -0.987           0.324
# L5.WS                      0.028660         0.046980            0.610           0.542
# L6.No of Vehicles          0.085958         0.109128            0.788           0.431
# L6.WS                      0.091096         0.047101            1.934           0.053
# L7.No of Vehicles          0.027676         0.108902            0.254           0.799
# L7.WS                     -0.017665         0.047145           -0.375           0.708
# L8.No of Vehicles         -0.121196         0.108560           -1.116           0.264
# L8.WS                      0.053455         0.047090            1.135           0.256
# L9.No of Vehicles          0.158720         0.108549            1.462           0.144
# L9.WS                      0.001973         0.046899            0.042           0.966
# L10.No of Vehicles        -0.102566         0.108672           -0.944           0.345
# L10.WS                     0.037270         0.047036            0.792           0.428
# L11.No of Vehicles         0.045292         0.108809            0.416           0.677
# L11.WS                    -0.002753         0.046805           -0.059           0.953
# L12.No of Vehicles         0.048438         0.108963            0.445           0.657
# L12.WS                     0.071054         0.046491            1.528           0.126
# L13.No of Vehicles        -0.139575         0.108914           -1.282           0.200
# L13.WS                    -0.026506         0.046617           -0.569           0.570
# L14.No of Vehicles         0.239254         0.109081            2.193           0.028
# L14.WS                     0.111387         0.046481            2.396           0.017
# L15.No of Vehicles        -0.171779         0.109505           -1.569           0.117
# L15.WS                     0.029017         0.046764            0.620           0.535
# L16.No of Vehicles        -0.055502         0.109640           -0.506           0.613
# L16.WS                    -0.037094         0.046765           -0.793           0.428
# L17.No of Vehicles         0.161665         0.109756            1.473           0.141
# L17.WS                    -0.028451         0.046674           -0.610           0.542
# L18.No of Vehicles        -0.162775         0.110063           -1.479           0.139
# L18.WS                     0.006776         0.046600            0.145           0.884
# L19.No of Vehicles         0.028019         0.110638            0.253           0.800
# L19.WS                     0.048585         0.046788            1.038           0.299
# L20.No of Vehicles        -0.066806         0.110653           -0.604           0.546
# L20.WS                     0.024053         0.046797            0.514           0.607
# L21.No of Vehicles         0.126173         0.110364            1.143           0.253
# L21.WS                    -0.071051         0.046896           -1.515           0.130
# L22.No of Vehicles         0.036751         0.110398            0.333           0.739
# L22.WS                     0.019145         0.046870            0.408           0.683
# L23.No of Vehicles        -0.060002         0.109766           -0.547           0.585
# L23.WS                     0.035929         0.046515            0.772           0.440
# L24.No of Vehicles        -0.039545         0.109725           -0.360           0.719
# L24.WS                    -0.089170         0.046178           -1.931           0.053
# L25.No of Vehicles         0.033490         0.079874            0.419           0.675
# L25.WS                     0.007587         0.043817            0.173           0.863
# =====================================================================================
#
# Correlation matrix of residuals
#                   No of Vehicles        WS
# No of Vehicles          1.000000  0.088774
# WS                      0.088774  1.000000

# %%
laaged_values = train.values[-25:]

forecast = pd.DataFrame(results.forecast(y= laaged_values, steps=len(valid)), index = valid.index, columns=valid.columns + '_1d')
forecast.head()
# Out:
#                      No of Vehicles_1d       WS_1d
# Date_Time
# 2022-10-25 18:59:59        6216.647458 -574.347825
# 2022-10-25 20:00:00        5632.681633 -503.374522
# 2022-10-25 21:00:00        4699.546212 -423.644192
# 2022-10-25 21:59:59        4152.324591 -440.578014
# 2022-10-25 23:00:00        3717.986317 -628.209041

# %%
# Plotting the results and actual values
plt.figure(figsize=(10,6))
plt.plot(valid['No of Vehicles'], label='Valid')
plt.plot(forecast['No of Vehicles_1d'], label='Prediction')
plt.legend(loc='best')
plt.title("VAR Model")
plt.show()

# %%
# Calculate RMSE
rms = np.sqrt(mean_squared_error(valid['No of Vehicles'].values, forecast['No of Vehicles_1d'].values))
print("RMSE: ", rms)
# Out:
# RMSE:  1210.0766199927627

# %% [markdown]
# # Random Forest Regression

# %%
rf = RandomForestRegressor()

rf.fit(X_train_lagged, y_train_lagged)
pred_rf = rf.predict(X_test_lagged)

# Calculate RMSE
print(np.sqrt(mean_squared_error(pred_rf, y_test_lagged)))
# Out:
# 337.4913128069208

# %%
# Plotting the results and actual values
plt.figure(figsize=(10,6))
plt.plot(y_test_lagged.values, label='Valid')
plt.plot(pred_rf, label='Prediction')
plt.legend(loc='best')
plt.title("VAR Model")
plt.show()

# %% [markdown]
# # Adaboost Regression

# %%
adaboost = AdaBoostRegressor()

adaboost.fit(X_train_lagged, y_train_lagged)
pred_adaboost = adaboost.predict(X_test_lagged)

# Calculate RMSE
print(np.sqrt(mean_squared_error(pred_adaboost, y_test_lagged)))
# Out:
# 456.43661251617874

# %%
# Plotting the results and actual values
plt.figure(figsize=(10,6))
plt.plot(y_test_lagged.values, label='Valid')
plt.plot(pred_adaboost, label='Prediction')
plt.legend(loc='best')
plt.title("Adaboost Model")
plt.show()

# %% [markdown]
# # XGBoost Model

# %%
xgboost = xgb.XGBRegressor()

xgboost.fit(X_train_lagged, y_train_lagged)
pred_xgboost = xgboost.predict(X_test_lagged)

# Calculate RMSE
print(np.sqrt(mean_squared_error(pred_xgboost, y_test_lagged)))
# Out:
# 334.0238841325591

# %%
# Plotting the results and actual values
plt.figure(figsize=(10,6))
plt.plot(y_test_lagged.values, label='Valid')
plt.plot(pred_xgboost, label='Prediction')
plt.legend(loc='best')
plt.title("XGBoost Model")
plt.show()

# %% [markdown]
# # Save all the models

# %%
# Save VAR model
pickle.dump(results, open('VAR_WindSpeed.pkl', 'wb'))

# %%
# Save XGBoost model
pickle.dump(xgboost, open('XGBoost_WindSpeed.pkl', 'wb'))

# %%
# Save Adaboost model
pickle.dump(adaboost, open('Adaboost_WindSpeed.pkl', 'wb'))

# %%
# Save Random Forest model
pickle.dump(rf, open('RandomForest_WindSpeed.pkl', 'wb'))
