# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
import pickle

from statsmodels.tsa.vector_ar.var_model import VAR

import xgboost as xgb
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# # Data

# %%
df = pd.read_csv('SECTIONNN.csv', parse_dates=[['Date', 'Time']])
df['Date_Time'] = pd.to_datetime(df.Date_Time , format = '%d/%m/%Y %H.%M.%S')
# Sort on time
df = df.sort_values(by='Date_Time')

df.head()
# Out:
#              Date_Time  No of Vehicles  Wind Speed  Visibility  Accident
# 23 2022-10-01 00:00:00            4523          17        16.0         3
# 0  2022-10-01 01:00:00            3434           6        16.0         3
# 1  2022-10-01 02:00:00            2229           7        16.0         5
# 2  2022-10-01 03:00:00            1583          19        16.0         4
# 3  2022-10-01 04:00:00            1360          15        16.0         3

# %%
# Plot correlation matrix
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# /tmp/ipykernel_13316/3037099363.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
# <style type="text/css">
# #T_6426c_row0_col0, #T_6426c_row1_col1, #T_6426c_row2_col2, #T_6426c_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6426c_row0_col1 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_6426c_row0_col2 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_6426c_row0_col3, #T_6426c_row3_col2 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_6426c_row1_col0, #T_6426c_row1_col2, #T_6426c_row2_col1, #T_6426c_row2_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6426c_row1_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_6426c_row2_col0 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_6426c_row3_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_6426c_row3_col1 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6426c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6426c_level0_col0" class="col_heading level0 col0" >No of Vehicles</th>
#       <th id="T_6426c_level0_col1" class="col_heading level0 col1" >Wind Speed</th>
#       <th id="T_6426c_level0_col2" class="col_heading level0 col2" >Visibility</th>
#       <th id="T_6426c_level0_col3" class="col_heading level0 col3" >Accident</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6426c_level0_row0" class="row_heading level0 row0" >No of Vehicles</th>
#       <td id="T_6426c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_6426c_row0_col1" class="data row0 col1" >0.023259</td>
#       <td id="T_6426c_row0_col2" class="data row0 col2" >0.152720</td>
#       <td id="T_6426c_row0_col3" class="data row0 col3" >0.028810</td>
#     </tr>
#     <tr>
#       <th id="T_6426c_level0_row1" class="row_heading level0 row1" >Wind Speed</th>
#       <td id="T_6426c_row1_col0" class="data row1 col0" >0.023259</td>
#       <td id="T_6426c_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_6426c_row1_col2" class="data row1 col2" >-0.082483</td>
#       <td id="T_6426c_row1_col3" class="data row1 col3" >0.014574</td>
#     </tr>
#     <tr>
#       <th id="T_6426c_level0_row2" class="row_heading level0 row2" >Visibility</th>
#       <td id="T_6426c_row2_col0" class="data row2 col0" >0.152720</td>
#       <td id="T_6426c_row2_col1" class="data row2 col1" >-0.082483</td>
#       <td id="T_6426c_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_6426c_row2_col3" class="data row2 col3" >-0.026813</td>
#     </tr>
#     <tr>
#       <th id="T_6426c_level0_row3" class="row_heading level0 row3" >Accident</th>
#       <td id="T_6426c_row3_col0" class="data row3 col0" >0.028810</td>
#       <td id="T_6426c_row3_col1" class="data row3 col1" >0.014574</td>
#       <td id="T_6426c_row3_col2" class="data row3 col2" >-0.026813</td>
#       <td id="T_6426c_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Plot the data
df.plot(x='Date_Time', y=['No of Vehicles'], figsize=(20,10))
# Out:
# <AxesSubplot: xlabel='Date_Time'>

# %%
# Check if data is stationary
from statsmodels.tsa.stattools import adfuller

result = adfuller(df['No of Vehicles'].values)
print('ADF Statistic: %f' % result[1])
# Out:
# ADF Statistic: 0.005820

# %%
# Partial Autocorrelation
from statsmodels.graphics.tsaplots import plot_pacf

plot_pacf(df['No of Vehicles'].values, lags=50)
# Out:
# /mnt/A6E6E098E6E069CF/L4T2/Extra/ML/Notebook/env/lib/python3.10/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# The stationary test returns p value less than 0.05, so it is stationary and no transformation is needed
#
# The partial autocorrelation shows that 1-5, 7-10, 25, 30 and so on lags can be used.

# %% [markdown]
# # Split data

# %%
data = df.drop(['Date_Time'], axis=1)
data.index = df.Date_Time

#creating the train and validation set for VAR model
train = data[:int(0.8*(len(data)))]
valid = data[int(0.8*(len(data))):]

# %%
# Create dataframes for train and valid for multivariate regression
X = data.drop(['No of Vehicles'], axis=1)
y = data['No of Vehicles']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((595, 3), (149, 3), (595,), (149,))

# %%
# Add lags to the data
for i in range(1,26):
    df["lag_{}".format(i)] = df['No of Vehicles'].shift(i)
    
# Create train and test set from lagged data
df.dropna(inplace=True)
X = df.drop(['No of Vehicles', 'Date_Time'], axis=1)
y = df['No of Vehicles']

X_train_lagged, X_test_lagged, y_train_lagged, y_test_lagged = train_test_split(X, y, test_size=0.2, shuffle=False)

# %% [markdown]
# # VAR Model

# %%
forecasting_model = VAR(train)
# Out:
# /mnt/A6E6E098E6E069CF/L4T2/Extra/ML/Notebook/env/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
results_aic = []

for p in range(1,50):
    results = forecasting_model.fit(p)
    results_aic.append(results.aic)

# %%
sns.set()
plt.plot(list(np.arange(1,50,1)), results_aic)
plt.xlabel("Order")
plt.ylabel("AIC")
plt.show()

# %%
# Lowest AIC is 25, which matches the PACF plot
results = forecasting_model.fit(25)
results.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Fri, 19, May, 2023
# Time:                     02:11:22
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                    20.3355
# Nobs:                     570.000    HQIC:                   18.4572
# Log likelihood:          -7748.98    FPE:                3.16604e+07
# AIC:                      17.2555    Det(Omega_mle):     1.64864e+07
# --------------------------------------------------------------------
# Results for equation No of Vehicles
# =====================================================================================
#                         coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------
# const                    677.103135       725.853855            0.933           0.351
# L1.No of Vehicles          0.947558         0.044940           21.085           0.000
# L1.Wind Speed              2.434970         5.765959            0.422           0.673
# L1.Visibility            -15.148277        10.386801           -1.458           0.145
# L1.Accident               38.348971        23.753589            1.614           0.106
# L2.No of Vehicles         -0.054783         0.061284           -0.894           0.371
# L2.Wind Speed            -13.503213         6.045485           -2.234           0.026
# L2.Visibility              4.273645        11.356751            0.376           0.707
# L2.Accident                3.530104        23.761946            0.149           0.882
# L3.No of Vehicles         -0.113413         0.061229           -1.852           0.064
# L3.Wind Speed             -0.771881         6.116608           -0.126           0.900
# L3.Visibility              6.298105        11.477691            0.549           0.583
# L3.Accident              -20.388811        23.755383           -0.858           0.391
# L4.No of Vehicles         -0.004339         0.061170           -0.071           0.943
# L4.Wind Speed             -0.013524         6.149664           -0.002           0.998
# L4.Visibility             22.283940        11.526912            1.933           0.053
# L4.Accident              -40.951965        23.809930           -1.720           0.085
# L5.No of Vehicles         -0.122699         0.060921           -2.014           0.044
# L5.Wind Speed              9.798247         6.154117            1.592           0.111
# L5.Visibility              9.214131        11.545882            0.798           0.425
# L5.Accident              -16.870781        23.818372           -0.708           0.479
# L6.No of Vehicles          0.029571         0.060889            0.486           0.627
# L6.Wind Speed             -6.107394         6.191125           -0.986           0.324
# L6.Visibility            -23.227023        11.503500           -2.019           0.043
# L6.Accident               16.324711        23.872942            0.684           0.494
# L13.Accident              -0.037111         0.045422           -0.817           0.414
# L14.No of Vehicles         0.000110         0.000118            0.935           0.350
# L14.Wind Speed            -0.006742         0.011893           -0.567           0.571
# L14.Visibility            -0.021396         0.021494           -0.995           0.320
# L14.Accident              -0.104132         0.045545           -2.286           0.022
# L15.No of Vehicles        -0.000235         0.000119           -1.986           0.047
# L15.Wind Speed            -0.006946         0.011937           -0.582           0.561
# L15.Visibility            -0.005159         0.021313           -0.242           0.809
# L15.Accident               0.031742         0.045875            0.692           0.489
# L16.No of Vehicles         0.000205         0.000119            1.726           0.084
# L16.Wind Speed            -0.002569         0.011935           -0.215           0.830
# L16.Visibility            -0.010050         0.021425           -0.469           0.639
# L16.Accident               0.003483         0.045539            0.076           0.939
# L17.No of Vehicles         0.000068         0.000120            0.567           0.571
# L17.Wind Speed             0.015010         0.011857            1.266           0.206
# L17.Visibility             0.004367         0.021258            0.205           0.837
# L17.Accident              -0.050787         0.045521           -1.116           0.265
# L18.No of Vehicles        -0.000100         0.000119           -0.838           0.402
# L18.Wind Speed            -0.005532         0.011821           -0.468           0.640
# L18.Visibility             0.029547         0.021186            1.395           0.163
# L18.Accident              -0.084211         0.045468           -1.852           0.064
# L19.No of Vehicles         0.000019         0.000120            0.156           0.876
# L19.Wind Speed             0.019592         0.011858            1.652           0.099
# L19.Visibility            -0.013081         0.020950           -0.624           0.532
# L19.Accident               0.050529         0.045445            1.112           0.266
# L20.No of Vehicles        -0.000060         0.000120           -0.504           0.614
# L20.Wind Speed            -0.005148         0.011910           -0.432           0.666
# L20.Visibility            -0.027446         0.020856           -1.316           0.188
# L20.Accident              -0.007256         0.045437           -0.160           0.873
# L21.No of Vehicles        -0.000112         0.000119           -0.936           0.349
# L21.Wind Speed            -0.000194         0.011901           -0.016           0.987
# L21.Visibility             0.038926         0.020767            1.874           0.061
# L21.Accident               0.011047         0.045628            0.242           0.809
# L22.No of Vehicles         0.000175         0.000120            1.466           0.143
# L22.Wind Speed            -0.002018         0.011836           -0.171           0.865
# L22.Visibility             0.013857         0.020758            0.668           0.504
# L22.Accident               0.031146         0.045509            0.684           0.494
# L23.No of Vehicles         0.000001         0.000119            0.007           0.994
# L23.Wind Speed            -0.007164         0.011645           -0.615           0.538
# L23.Visibility            -0.015989         0.020701           -0.772           0.440
# L23.Accident               0.048563         0.046111            1.053           0.292
# L24.No of Vehicles         0.000063         0.000119            0.531           0.596
# L24.Wind Speed            -0.010394         0.011609           -0.895           0.371
# L24.Visibility             0.005175         0.020667            0.250           0.802
# L24.Accident              -0.070372         0.045996           -1.530           0.126
# L25.No of Vehicles        -0.000095         0.000087           -1.093           0.274
# L25.Wind Speed            -0.000350         0.010993           -0.032           0.975
# L25.Visibility            -0.013054         0.019288           -0.677           0.499
# L25.Accident              -0.109354         0.045751           -2.390           0.017
# =====================================================================================
#
# Correlation matrix of residuals
#                   No of Vehicles  Wind Speed  Visibility  Accident
# No of Vehicles          1.000000   -0.083620    0.065149 -0.023648
# Wind Speed             -0.083620    1.000000    0.012529  0.039254
# Visibility              0.065149    0.012529    1.000000 -0.002789
# Accident               -0.023648    0.039254   -0.002789  1.000000

# %%
laaged_values = train.values[-25:]

forecast = pd.DataFrame(results.forecast(y= laaged_values, steps=len(valid)), index = valid.index, columns=valid.columns + '_1d')
forecast.head()
# Out:
#                      No of Vehicles_1d  Wind Speed_1d  Visibility_1d  \
# Date_Time
# 2022-10-25 18:59:59        6059.547756       0.932409      12.517902
# 2022-10-25 20:00:00        5606.279554       0.237836      13.236377
# 2022-10-25 21:00:00        4828.517968       0.653665      11.841472
# 2022-10-25 21:59:59        4203.277718       0.218245      12.971427
# 2022-10-25 23:00:00        3607.279708      -0.857495      14.676007
#
#                      Accident_1d
# Date_Time
# 2022-10-25 18:59:59     4.015267
# 2022-10-25 20:00:00     3.993842
# 2022-10-25 21:00:00     3.339294
# 2022-10-25 21:59:59     4.204650
# 2022-10-25 23:00:00     4.621334

# %%
# Plotting the results and actual values
plt.figure(figsize=(10,6))
plt.plot(valid['No of Vehicles'], label='Valid')
plt.plot(forecast['No of Vehicles_1d'], label='Prediction')
plt.legend(loc='best')
plt.title("VAR Model")
plt.show()

# %%
# Calculate RMSE
rms = np.sqrt(mean_squared_error(valid['No of Vehicles'].values, forecast['No of Vehicles_1d'].values))
print("RMSE: ", rms)
# Out:
# RMSE:  1514.6295822704058

# %% [markdown]
# # Random Forest Regression

# %%
rf = RandomForestRegressor()

rf.fit(X_train_lagged, y_train_lagged)
pred_rf = rf.predict(X_test_lagged)

# Calculate RMSE
print(np.sqrt(mean_squared_error(pred_rf, y_test_lagged)))
# Out:
# 340.15540810956844

# %%
# Plotting the results and actual values
plt.figure(figsize=(10,6))
plt.plot(y_test_lagged.values, label='Valid')
plt.plot(pred_rf, label='Prediction')
plt.legend(loc='best')
plt.title("VAR Model")
plt.show()

# %% [markdown]
# # Adaboost Regression

# %%
adaboost = AdaBoostRegressor()

adaboost.fit(X_train_lagged, y_train_lagged)
pred_adaboost = adaboost.predict(X_test_lagged)

# Calculate RMSE
print(np.sqrt(mean_squared_error(pred_adaboost, y_test_lagged)))
# Out:
# 454.38074041630773

# %%
# Plotting the results and actual values
plt.figure(figsize=(10,6))
plt.plot(y_test_lagged.values, label='Valid')
plt.plot(pred_adaboost, label='Prediction')
plt.legend(loc='best')
plt.title("Adaboost Model")
plt.show()

# %% [markdown]
# # XGBoost Model

# %%
xgboost = xgb.XGBRegressor()

xgboost.fit(X_train_lagged, y_train_lagged)
pred_xgboost = xgboost.predict(X_test_lagged)

# Calculate RMSE
print(np.sqrt(mean_squared_error(pred_xgboost, y_test_lagged)))
# Out:
# 347.01645906647286

# %%
# Plotting the results and actual values
plt.figure(figsize=(10,6))
plt.plot(y_test_lagged.values, label='Valid')
plt.plot(pred_xgboost, label='Prediction')
plt.legend(loc='best')
plt.title("XGBoost Model")
plt.show()

# %% [markdown]
# # Save all the models

# %%
# Save VAR model
pickle.dump(results, open('VAR_Latest.pkl', 'wb'))

# %%
# Save XGBoost model
pickle.dump(xgboost, open('XGBoost_Latest.pkl', 'wb'))

# %%
# Save Adaboost model
pickle.dump(adaboost, open('Adaboost_Latest.pkl', 'wb'))

# %%
# Save Random Forest model
pickle.dump(rf, open('RandomForest_Latest.pkl', 'wb'))
